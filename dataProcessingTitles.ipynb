# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import glob
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM, BatchNormalization, GlobalAveragePooling1D
from sklearn.metrics import classification_report
from scipy.stats import skew, kurtosis
import requests

# %%
API_BASE_URL = "https://bills-api.parliament.uk/api/v1/Bills"

# %%
def get_bill_info(bill_id):
    url = f"{API_BASE_URL}/{bill_id}"
    headers = {"accept": "application/json"}
    response = requests.get(url, headers=headers)
    try:
        data = response.json()
        if isinstance (data, dict):
            long_title = data.get("longTitle", "N/A")
            short_title = data.get("shortTitle", "N/A")
            orig_house = data.get("originatingHouse", "N/A")
            status = check_bill_progress(bill_id)
            sessionID = data.get("introducedSessionId", "N/A")
           
            
            return bill_id, long_title, short_title, orig_house, status, sessionID
    except requests.exceptions.JSONDecodeError:
        print(f"Error: Response for Bill ID {bill_id} is not valid JSON. Response:", response.text)
        return False

# %%
def count_bills_in_session(session_id):
    """Fetch the number of bills that contain a specific session ID."""
    params = {
        "Session": session_id,
        "Take": 1  # Only request one item to check total count
    }
    
    headers = {"accept": "application/json"}
    response = requests.get(API_BASE_URL, headers=headers, params=params)

    try:
        data = response.json()
        if isinstance(data, dict) and "totalResults" in data:
            return data["totalResults"]  # Total number of bills with this session ID
        else:
            print("Unexpected API response format:", data)
            return 0
    except requests.exceptions.JSONDecodeError:
        print("Error: Response is not valid JSON. Response:", response.text)
        return 0
    
print (count_bills_in_session(37))
# Out:
# 355

# %%
def check_bill_progress(bill_id):
    """Checks if a bill is an act using the isAct field from the API."""
    url = f"https://bills-api.parliament.uk/api/v1/Bills/{bill_id}"  
    headers = {"accept": "application/json"}  
    
    response = requests.get(url, headers=headers)

    try:
        data = response.json()  
        if 'isAct' in data:
            return 2 if data['isAct'] else 1
        else:
            print(f"'isAct' field not found for Bill ID {bill_id}")
            return 3  

    except requests.exceptions.JSONDecodeError:
        print(f"Error: Response for Bill ID {bill_id} is not valid JSON. Response:", response.text)
        return False
print (
check_bill_progress_2(799))
# Out:
# 2

# %%
def populate_dataframes(bills, f_commons, f_lords, s_commons, s_lords, weird):
    columns1 = ["Bill Id", "Long Title", "Short Title", "Origin_House", "Status", "SessionID"]

    rows_f_commons, rows_f_lords, rows_s_commons, rows_s_lords, rows_weird = [], [], [], [], []
    
    for bill in bills:
        bill_id = bill.get("billId", "N/A")
        bill_id, long_title, short_title, orig_house, status, sessionID = get_bill_info(bill_id)
        
        new_row = [bill_id, long_title, short_title, orig_house, status, sessionID]
        
        if status == 1:
            if orig_house == "Commons":
                rows_f_commons.append(new_row)
            elif orig_house == "Lords":
                rows_f_lords.append(new_row)
        elif status == 2:
            if orig_house == "Commons":
                rows_s_commons.append(new_row)
            elif orig_house == "Lords":
                rows_s_lords.append(new_row)
        elif status == 3:
            rows_weird.append(new_row)
    

    f_commons = pd.concat([pd.DataFrame(rows_f_commons, columns=columns1), f_commons], ignore_index=True)
    f_lords = pd.concat([pd.DataFrame(rows_f_lords, columns=columns1), f_lords], ignore_index=True)
    s_commons = pd.concat([pd.DataFrame(rows_s_commons, columns=columns1), s_commons], ignore_index=True)
    s_lords = pd.concat([pd.DataFrame(rows_s_lords, columns=columns1), s_lords], ignore_index=True)
    weird = pd.concat([pd.DataFrame(rows_weird, columns=columns1), weird], ignore_index=True)
    
    return f_commons, f_lords, s_commons, s_lords, weird

# %%
import datetime




#last session 39
columns = ["Bill Id", "Long Title", "Short Title", "Origin_House", "Status", "SessionID"]

S_commons0 = pd.DataFrame(columns=columns)
F_commons0 = pd.DataFrame(columns=columns)
S_lords0 = pd.DataFrame(columns=columns)
F_lords0 = pd.DataFrame(columns=columns)
weirdList0 = pd.DataFrame(columns=columns)



def get_bills_by_session(session_id, num_bills):
    """Fetch bills from a specific session ID."""
    params = {
        "Session": session_id,
        "Take": num_bills  
    }
    
    headers = {"accept": "application/json"}
    response = requests.get(API_BASE_URL, headers=headers, params=params)

    try:
        data = response.json()
        if isinstance(data, dict) and "items" in data:
            return data["items"]  
        else:
            print("Unexpected API response format:", data)
            return []
    except requests.exceptions.JSONDecodeError:
        print("Error: Response is not valid JSON. Response:", response.text)
        return []
    



session_id = int(input("Enter Session ID: "))
#num_bills = int(input("Enter number of bills to retrieve: "))






start_session = session_id
end_session = 39 

#num_bills0= count_bills_in_session(session_id)
#bills0= get_bills_by_session(session_id, num_bills)


now = datetime.datetime.now()

# Print just the time part
print("Code starts executing at :", now.strftime("%H:%M:%S"))  
    

    
    
for session in range(start_session, end_session + 1):
    now = datetime.datetime.now()
    print(f"counting bills in session {session} starts at :", now.strftime("%H:%M:%S"))  
    num_bills = count_bills_in_session(session)
    now = datetime.datetime.now()
    print(f"counting bills in session {session} finish at :", now.strftime("%H:%M:%S"))  
    bills0 = get_bills_by_session(session, num_bills)
    now = datetime.datetime.now()
    print(f"Bills0 computed for session {session} finish at :", now.strftime("%H:%M:%S"))  
    
    F_commons0 , F_lords0, S_commons0, S_lords0, weirdList0 = populate_dataframes(bills0, F_commons0, F_lords0, S_commons0, S_lords0, weirdList0)    
    
    now = datetime.datetime.now()
    print(f"Dataframes appended at {session} finish at :", now.strftime("%H:%M:%S"))
    



display(F_commons0)
display(F_lords0)
display(S_commons0)
display(S_lords0)


#print ("This is the weird list")
#display(weirdList0)

F_commons0.to_csv(   f"18_{start_session} to {end_session}.csv"   , index=False)
F_lords0.to_csv(     f"19_{start_session} to {end_session}.csv"   , index = False )
S_lords0.to_csv(     f"29_{start_session} to {end_session}.csv", index = False )
S_commons0.to_csv(   f"28_{start_session} to {end_session}.csv", index= False)
weirdList0.to_csv(   f"errors {start_session} to {end_session}.csv", index= False )



print("Code finished executing ")
# Get the current datetime
now2 = datetime.datetime.now()

# Print just the time part
print("Time Code Finished Executing:", now2.strftime("%H:%M:%S"))
# Out:
# Enter Session ID: 17
# Code starts executing at : 01:47:36
# counting bills in session 17 starts at : 01:47:36
# counting bills in session 17 finish at : 01:47:38
# Bills0 computed for session 17 finish at : 01:47:38
# Dataframes appended at 17 finish at : 01:47:38
# counting bills in session 18 starts at : 01:47:38
# counting bills in session 18 finish at : 01:47:40
# Bills0 computed for session 18 finish at : 01:47:42
# Dataframes appended at 18 finish at : 01:47:42
# counting bills in session 19 starts at : 01:47:42
# counting bills in session 19 finish at : 01:47:43
# Bills0 computed for session 19 finish at : 01:47:44
# Dataframes appended at 19 finish at : 01:47:47
# counting bills in session 20 starts at : 01:47:47
# counting bills in session 20 finish at : 01:47:47
# Bills0 computed for session 20 finish at : 01:47:49
# Dataframes appended at 20 finish at : 01:49:51
# counting bills in session 21 starts at : 01:49:51
# counting bills in session 21 finish at : 01:49:52
# Bills0 computed for session 21 finish at : 01:49:53
# Dataframes appended at 21 finish at : 01:51:24
# counting bills in session 22 starts at : 01:51:24
# counting bills in session 22 finish at : 01:51:24
# Bills0 computed for session 22 finish at : 01:51:25
# Dataframes appended at 22 finish at : 01:53:10
# counting bills in session 23 starts at : 01:53:10
# counting bills in session 23 finish at : 01:53:11
# Bills0 computed for session 23 finish at : 01:53:12
# Dataframes appended at 23 finish at : 01:54:35
# counting bills in session 24 starts at : 01:54:35
# counting bills in session 24 finish at : 01:54:36
# Bills0 computed for session 24 finish at : 01:54:40
# Dataframes appended at 24 finish at : 01:58:05
# counting bills in session 25 starts at : 01:58:05
# counting bills in session 25 finish at : 01:58:05
# Bills0 computed for session 25 finish at : 01:58:06
# Dataframes appended at 25 finish at : 01:59:51
# counting bills in session 26 starts at : 01:59:51
# counting bills in session 26 finish at : 01:59:52
# Bills0 computed for session 26 finish at : 01:59:53
# Dataframes appended at 26 finish at : 02:02:10
# counting bills in session 27 starts at : 02:02:10
# counting bills in session 27 finish at : 02:02:10
# Bills0 computed for session 27 finish at : 02:02:12
# Dataframes appended at 27 finish at : 02:04:17
# counting bills in session 28 starts at : 02:04:17
# counting bills in session 28 finish at : 02:04:17
# Bills0 computed for session 28 finish at : 02:04:19
# Dataframes appended at 28 finish at : 02:06:27
# counting bills in session 29 starts at : 02:06:27
# counting bills in session 29 finish at : 02:06:27
# Bills0 computed for session 29 finish at : 02:06:29
# Dataframes appended at 29 finish at : 02:08:51
# counting bills in session 30 starts at : 02:08:51
# counting bills in session 30 finish at : 02:08:52
# Bills0 computed for session 30 finish at : 02:08:54
# Dataframes appended at 30 finish at : 02:14:44
# counting bills in session 31 starts at : 02:14:44
# counting bills in session 31 finish at : 02:14:45
# Bills0 computed for session 31 finish at : 02:14:45
# Dataframes appended at 31 finish at : 02:14:45
# counting bills in session 32 starts at : 02:14:45
# counting bills in session 32 finish at : 02:14:48
# Bills0 computed for session 32 finish at : 02:14:49
# Dataframes appended at 32 finish at : 02:14:49
# counting bills in session 33 starts at : 02:14:49
# counting bills in session 33 finish at : 02:14:50
# Bills0 computed for session 33 finish at : 02:14:50
# Dataframes appended at 33 finish at : 02:14:50
# counting bills in session 34 starts at : 02:14:50
# counting bills in session 34 finish at : 02:14:51
# Bills0 computed for session 34 finish at : 02:14:51
# Dataframes appended at 34 finish at : 02:15:36
# counting bills in session 35 starts at : 02:15:36
# counting bills in session 35 finish at : 02:15:37
# Bills0 computed for session 35 finish at : 02:15:38
# Dataframes appended at 35 finish at : 02:19:38
# counting bills in session 36 starts at : 02:19:38
# counting bills in session 36 finish at : 02:19:40
# Bills0 computed for session 36 finish at : 02:19:42
# Dataframes appended at 36 finish at : 02:22:58
# counting bills in session 37 starts at : 02:22:58
# counting bills in session 37 finish at : 02:22:59
# Bills0 computed for session 37 finish at : 02:23:01
# Dataframes appended at 37 finish at : 02:26:13
# counting bills in session 38 starts at : 02:26:13
# counting bills in session 38 finish at : 02:26:14
# Bills0 computed for session 38 finish at : 02:26:15
# Dataframes appended at 38 finish at : 02:28:22
# counting bills in session 39 starts at : 02:28:22
# counting bills in session 39 finish at : 02:28:22
# Bills0 computed for session 39 finish at : 02:28:24
# Dataframes appended at 39 finish at : 02:30:28
#      Bill Id                                         Long Title  \
# 0       3785  A Bill to make provision about absent voting i...
# 1       3800  A Bill to require providers of electronic comm...
# 2       3814  A Bill to prohibit the granting of planning pe...
# 3       3790  A Bill to make provision for and in connection...
# 4       3798  A Bill to require a person in charge of a dog ...
# ...      ...                                                ...
# 2411     106                                               None
# 2412     107  Make provision for the law relating to the rig...
# 2413     129  Require the Secretary of State to lay before t...
# 2414     141                                               None
# 2415     142                                               None
#
#                                             Short Title Origin_House Status  \
# 0     Absent Voting (Elections in Scotland and Wales...      Commons      1
# 1            Access to Telecommunications Networks Bill      Commons      1
# 2                     Agricultural Land (Planning) Bill      Commons      1
# 3     Animal Welfare (Import of Dogs, Cats and Ferre...      Commons      1
# 4     Animal Welfare (Responsibility for Dog on Dog ...      Commons      1
# ...                                                 ...          ...    ...
# 2411         Town and Country Planning (Amendment) Bill      Commons      1
# 2412               Trade Union Rights and Freedoms Bill      Commons      1
# 2413  Waging War (Parliament's Role and Responsibilt...      Commons      1
# 2414                       Wild Birds (Protection) Bill      Commons      1
# 2415  Young Offenders (Provision of Speech Therapy) ...      Commons      1
#
#      SessionID
# 0           39
# 1           39
# 2           39
# 3           39
# 4           39
# ...        ...
# 2411        20
# 2412        20
# 2413        20
# 2414        20
# 2415        20
#
# [2416 rows x 6 columns]
#     Bill Id                                         Long Title  \
# 0      3942  A bill to make provision for the regulation of...
# 1      3741  A Bill to allow adults who are terminally ill,...
# 2      3758  A Bill to introduce a minimum period of 56 day...
# 3      3734  A Bill to make provision about recapitalisatio...
# 4      3910  A bill to make provision about local and schoo...
# ..      ...                                                ...
# 677      63  Make provision for the establishment of a Roya...
# 678     100  Make provision about the advertising of food p...
# 679     105  Make provision for actions for damages for tor...
# 680     621  A Bill to confer further powers upon Transport...
# 681     127  Make provision for advice and assistance to vi...
#
#                                            Short Title Origin_House Status  \
# 0       Artificial Intelligence (Regulation) Bill [HL]        Lords      1
# 1    Assisted Dying for Terminally Ill Adults Bill ...        Lords      1
# 2         Asylum Support (Prescribed Period) Bill [HL]        Lords      1
# 3         Bank Resolution (Recapitalisation) Bill [HL]        Lords      1
# 4                       Bus Services (No. 2) Bill [HL]        Lords      1
# ..                                                 ...          ...    ...
# 677               Royal Commission (Slavery) Bill [HL]        Lords      1
# 678            Television Advertising (Food) Bill [HL]        Lords      1
# 679                        Torture (Damages) Bill [HL]        Lords      1
# 680  Transport for London (Supplemental Toll Provis...        Lords      1
# 681            Victims of Overseas Terrorism Bill [HL]        Lords      1
#
#     SessionID
# 0          39
# 1          39
# 2          39
# 3          39
# 4          39
# ..        ...
# 677        20
# 678        20
# 679        20
# 680        20
# 681        20
#
# [682 rows x 6 columns]
#     Bill Id                                         Long Title  \
# 0      3731  A Bill to impose duties on the Treasury and th...
# 1      3882  A Bill to make provision for loans or other fi...
# 2      3732  A Bill to make provision for passenger railway...
# 3      3736  A Bill to authorise the use of resources for t...
# 4      3533  A Bill to Prohibit the export of certain lives...
# ..      ...                                                ...
# 554     140  Make provision for a railway transport system ...
# 555     208  To confer further powers upon local authoritie...
# 556     144  Make provision about social security; to amend...
# 557     140  Make provision for a railway transport system ...
# 558     208  To confer further powers upon local authoritie...
#
#                                            Short Title Origin_House Status  \
# 0                       Budget Responsibility Act 2024      Commons      2
# 1             Financial Assistance to Ukraine Act 2025      Commons      2
# 2    Passenger Railway Services (Public Ownership) ...      Commons      2
# 3    Supply and Appropriation (Main Estimates) Act ...      Commons      2
# 4          Animal Welfare (Livestock Exports) Act 2024      Commons      2
# ..                                                 ...          ...    ...
# 554                                 Crossrail Act 2008      Commons      2
# 555  LONDON LOCAL AUTHORITIES AND TRANSPORT FOR LON...      Commons      2
# 556                            Welfare Reform Act 2007      Commons      2
# 557                                 Crossrail Act 2008      Commons      2
# 558  LONDON LOCAL AUTHORITIES AND TRANSPORT FOR LON...      Commons      2
#
#     SessionID
# 0          39
# 1          39
# 2          39
# 3          39
# 4          38
# ..        ...
# 554        18
# 555        18
# 556        19
# 557        18
# 558        18
#
# [559 rows x 6 columns]
#     Bill Id                                         Long Title  \
# 0      3733  A Bill to amend the Arbitration Act 1996; and ...
# 1      3735  A Bill to make provision about the status of, ...
# 2      3744  A Bill to extend the period within which vacan...
# 3      3751  A Bill to make provision about the regulation,...
# 4      3506  A Bill to regulate the use of automated vehicl...
# ..      ...                                                ...
# 175      84  To provide for joint departments of the Houses...
# 176      79  Make provision about serious crime prevention ...
# 177     210  To confer further powers upon Transport for Lo...
# 178     109  Make provision about tribunals and inquiries; ...
# 179     210  To confer further powers upon Transport for Lo...
#
#                                            Short Title Origin_House Status  \
# 0                                 Arbitration Act 2025        Lords      2
# 1    Commonwealth Parliamentary Association and Int...        Lords      2
# 2    Lords Spiritual (Women) Act 2015 (Extension) A...        Lords      2
# 3                    Water (Special Measures) Act 2025        Lords      2
# 4                          Automated Vehicles Act 2024        Lords      2
# ..                                                 ...          ...    ...
# 175            Parliament (Joint Departments) Act 2007        Lords      2
# 176                             Serious Crime Act 2007        Lords      2
# 177                      Transport for London Act 2008        Lords      2
# 178         Tribunals, Courts and Enforcement Act 2007        Lords      2
# 179                      Transport for London Act 2008        Lords      2
#
#     SessionID
# 0          39
# 1          39
# 2          39
# 3          39
# 4          38
# ..        ...
# 175        20
# 176        20
# 177        19
# 178        20
# 179        19
#
# [180 rows x 6 columns]
# Code finished executing
# Time Code Finished Executing: 02:30:29

# %%
total_bills = 0
yearsWithBills=0

for i in range (39,50):
    bills = count_bills_in_session(i)
    if bills != 0:
        yearsWithBills = yearsWithBills + 1
    print( (f"Bills in session {i} is {bills}"))
    total_bills = total_bills + bills
print(total_bills)
print (f"Years with bills {yearsWithBills}")
# Out:
# Bills in session 39 is 216
# Bills in session 40 is 0
# Bills in session 41 is 0
# Bills in session 42 is 0
# Bills in session 43 is 0
# Bills in session 44 is 0
# Bills in session 45 is 0
# Bills in session 46 is 0
# Bills in session 47 is 0
# Bills in session 48 is 0
# Bills in session 49 is 0
# 216
# Years with bills 1
